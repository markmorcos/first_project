# %%
# %load_ext autoreload
# %autoreload 2
import functions as f
#import pandas as pd

# %%
df_microsoft = f.load_ticker_data('MSFT')
df_microsoft.head()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 2019-11-01 00:00:00+00:00  137.274170  143.720001  144.419998  142.970001
# 2019-11-04 00:00:00+00:00  138.066910  144.550003  145.000000  144.160004
# 2019-11-05 00:00:00+00:00  137.980988  144.460007  145.020004  143.910004
# 2019-11-06 00:00:00+00:00  137.598907  144.059998  144.520004  143.199997
# 2019-11-07 00:00:00+00:00  137.789871  144.259995  144.880005  143.770004
#
# Price                            Open    Volume
# Ticker                           MSFT      MSFT
# Date
# 2019-11-01 00:00:00+00:00  144.259995  33128400
# 2019-11-04 00:00:00+00:00  144.830002  16912000
# 2019-11-05 00:00:00+00:00  144.970001  18250200
# 2019-11-06 00:00:00+00:00  144.369995  16575800
# 2019-11-07 00:00:00+00:00  143.839996  17786700

# %%
df_microsoft = f.normalize(df_microsoft)
df_microsoft.head()
# Out:
#                             adj_close       close        high         low  \
# date
# 2019-11-01 00:00:00+00:00  137.274170  143.720001  144.419998  142.970001
# 2019-11-04 00:00:00+00:00  138.066910  144.550003  145.000000  144.160004
# 2019-11-05 00:00:00+00:00  137.980988  144.460007  145.020004  143.910004
# 2019-11-06 00:00:00+00:00  137.598907  144.059998  144.520004  143.199997
# 2019-11-07 00:00:00+00:00  137.789871  144.259995  144.880005  143.770004
#
#                                  open    volume
# date
# 2019-11-01 00:00:00+00:00  144.259995  33128400
# 2019-11-04 00:00:00+00:00  144.830002  16912000
# 2019-11-05 00:00:00+00:00  144.970001  18250200
# 2019-11-06 00:00:00+00:00  144.369995  16575800
# 2019-11-07 00:00:00+00:00  143.839996  17786700

# %%
df_microsoft = f.create_date_column(df_microsoft)
df_microsoft.head()
# Out:
#     adj_close       close        high         low        open    volume  \
# 0  137.274170  143.720001  144.419998  142.970001  144.259995  33128400
# 1  138.066910  144.550003  145.000000  144.160004  144.830002  16912000
# 2  137.980988  144.460007  145.020004  143.910004  144.970001  18250200
# 3  137.598907  144.059998  144.520004  143.199997  144.369995  16575800
# 4  137.789871  144.259995  144.880005  143.770004  143.839996  17786700
#
#         date
# 0 2019-11-01
# 1 2019-11-04
# 2 2019-11-05
# 3 2019-11-06
# 4 2019-11-07

# %%
df_microsoft, analysis_microsoft = f.analysis_df(df_microsoft, 'Microsoft')
df_microsoft.head()
# Out:
#     adj_close       close        high         low        open    volume  \
# 0  137.274170  143.720001  144.419998  142.970001  144.259995  33128400
# 1  138.066910  144.550003  145.000000  144.160004  144.830002  16912000
# 2  137.980988  144.460007  145.020004  143.910004  144.970001  18250200
# 3  137.598907  144.059998  144.520004  143.199997  144.369995  16575800
# 4  137.789871  144.259995  144.880005  143.770004  143.839996  17786700
#
#         date  daily_returns  daily_range
# 0 2019-11-01       0.577487     1.449997
# 1 2019-11-04       0.577487     0.839996
# 2 2019-11-05      -0.062232     1.110001
# 3 2019-11-06      -0.276908     1.320007
# 4 2019-11-07       0.138783     1.110001

# %%
analysis_microsoft.head()
# Out:
#          open     high      low    close  adj_close        volume  \
# mean  285.722  288.538  282.773  285.785    280.930  2.857858e+07
# std    80.449   80.673   79.952   80.339     82.166  1.271461e+07
#
#       daily_returns  daily_range  monthly_returns  annual_returns
# mean          0.108        5.765            2.011          27.786
# std           1.910        2.914            6.470          35.579

# %%
f.plot(df_microsoft, 'date', 'adj_close', 'Adjusted Closing Price of Microsoft Stock over time')

# %%
df_nvidia = f.load_ticker_data('NVDA')
df_nvidia = f.normalize(df_nvidia)
df_nvidia = f.create_date_column(df_nvidia)
df_nvidia, analysis_nvidia = f.analysis_df(df_nvidia, 'NVIDIA')
f.plot(df_nvidia, 'date', 'adj_close', 'Adjusted Closing Price of NVIDIA Stock over time')

# %%
df_jpm = f.load_ticker_data('JPM')
df_jpm = f.normalize(df_jpm)
df_jpm = f.create_date_column(df_jpm)
df_jpm, analysis_jpm = f.analysis_df(df_jpm, 'JP Morgan')
f.plot(df_jpm, 'date', 'adj_close', 'Adjusted Closing Price of JP Morgan Stock over time')

# %%
df_bac = f.load_ticker_data('BAC')
df_bac = f.normalize(df_bac)
df_bac = f.create_date_column(df_bac)
df_bac, analysis_bac = f.analysis_df(df_bac, 'Bank of America')
f.plot(df_bac, 'date', 'adj_close', 'Adjusted Closing Price of Bank of America Stock over time')

# %%
df_meta = f.load_ticker_data('META')
df_meta = f.normalize(df_meta)
df_meta = f.create_date_column(df_meta)
df_meta, analysis_meta = f.analysis_df(df_meta, 'META')
f.plot(df_meta, 'date', 'adj_close', 'Adjusted Closing Price of META Stock over time')

# %%
df_amzn = f.load_ticker_data('AMZN')
df_amzn = f.normalize(df_amzn)
df_amzn = f.create_date_column(df_amzn)
df_amzn, analysis_amzn = f.analysis_df(df_amzn, 'Amazon')
f.plot(df_amzn, 'date', 'adj_close', 'Adjusted Closing Price of Amazon Stock over time')

# %%
df_google = f.load_ticker_data('GOOG')
df_google = f.normalize(df_google)
df_google = f.create_date_column(df_google)
df_google, analysis_google = f.analysis_df(df_google, 'Google')
f.plot(df_google, 'date', 'adj_close', 'Adjusted Closing Price of Google Stock over time')

# %%
df_idcby = f.load_ticker_data('IDCBY')
df_idcby = f.normalize(df_idcby)
df_idcby = f.create_date_column(df_idcby)
df_idcby, analysis_idcby = f.analysis_df(df_idcby, 'Industrial and Commercial Bank of China')
f.plot(df_idcby, 'date', 'adj_close', 'Adjusted Closing Price of Industrial and Commercial Bank of China Stock over time')

# %%
df_wfc = f.load_ticker_data('WFC')
df_wfc = f.normalize(df_wfc)
df_wfc = f.create_date_column(df_wfc)
df_wfc, analysis_wfc = f.analysis_df(df_wfc, 'Wells Fargo & Co.')
f.plot(df_wfc, 'date', 'adj_close', 'Adjusted Closing Price of Wells Fargo & Co. Stock over time')

# %%
df_ensg = f.load_ticker_data('ENSG')
df_ensg = f.normalize(df_ensg)
df_ensg = f.create_date_column(df_ensg)
df_ensg, analysis_ensg = f.analysis_df(df_ensg, 'Ensign')
f.plot(df_ensg, 'date', 'adj_close', 'Adjusted Closing Price of Ensign Stock over time')

# %%
df_ubs = f.load_ticker_data('UBS')
df_ubs = f.normalize(df_ubs)
df_ubs = f.create_date_column(df_ubs)
df_ubs, analysis_ubs = f.analysis_df(df_ubs, 'UBS')
f.plot(df_ubs, 'date', 'adj_close', 'Adjusted Closing Price of UBS Stock over time')

# %%
df_gs = f.load_ticker_data('GS')
df_gs = f.normalize(df_gs)
df_gs = f.create_date_column(df_gs)
df_gs, analysis_gs = f.analysis_df(df_gs, 'Goldman Sachs')
f.plot(df_gs, 'date', 'adj_close', 'Adjusted Closing Price of Goldman Sachs Stock over time')

# %%
df_apple = f.load_ticker_data('AAPL')
df_apple = f.normalize(df_apple)
df_apple = f.create_date_column(df_apple)
df_apple, analysis_apple = f.analysis_df(df_apple, 'Apple')
f.plot(df_apple, 'date', 'adj_close', 'Adjusted Closing Price of Apple Stock over time')
