# %%
from datetime import datetime
import functions
import yfinance as yf

events = [
    { "name": "COVID", "date": datetime(2020, 3, 1) },
    { "name": "Something", "date": datetime(2021, 3, 1) },
    { "name": "Something Else", "date": datetime(2023, 3, 1) }
]

# %%
functions.plot_ticker("JPM", "adj_close", (datetime(2019, 11, 1), datetime(2024, 10, 31)), events)

# %%
functions.plot_ticker("BAC", "volume", (datetime(2019, 11, 1), datetime(2024, 10, 31)), events)
