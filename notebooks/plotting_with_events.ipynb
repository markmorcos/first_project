# %%
from datetime import datetime
import functions
import yfinance as yf

# %reload_ext autoreload
# %autoreload 2

events = [
    { "name": "COVID", "date": datetime(2020, 3, 1) },
    { "name": "4.2% CPI increase", "date": datetime(2021, 4, 1) },
    { "name": "Russia-Ukraine War", "date": datetime(2022, 2, 24) },
    { "name": "Silicon Valley Bank collapse", "date": datetime(2023, 3, 10) },
    
]

# %%
jpm_df = functions.plot_ticker("JPM", "adj_close", (datetime(2019, 11, 1), datetime(2024, 10, 31)), events)
jpm_df = functions.plot_plotly("

# %%
bac_df = functions.plot_ticker("BAC", "adj_close", (datetime(2019, 11, 1), datetime(2024, 10, 31)), events)

# %%
nvda_df = functions.plot_ticker("NVDA", "adj_close", (datetime(2019, 11, 1), datetime(2024, 10, 31)), events)
